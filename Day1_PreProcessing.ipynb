# %% [markdown]
# <a href="https://colab.research.google.com/github/j019/Practical-Machine-Learning-/blob/main/Day1_PreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files

# %%
df = pd.read_csv('Employee_attrition.csv',na_values=["NA"," "])

# %%
df.shape
# Out:
# (1470, 35)

# %%
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
for col in df.columns:
  print(col, df[col].unique())
# Out:
# Age [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# Attrition ['Yes' 'No']
# BusinessTravel ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# DailyRate [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
# ...

# %%
# FIND ALL CATEGORICAL COLUMNS
# thumb rule ---> no. of unique values < 15

for col in df.columns:
  if df[col].nunique() <=  15 :
    print(col)
# Out:
# Attrition
# BusinessTravel
# Department
# Education
# EducationField
# EmployeeCount
# EnvironmentSatisfaction
# Gender
# JobInvolvement
# JobLevel
# JobRole
# JobSatisfaction
# MaritalStatus
# NumCompaniesWorked
# Over18
# OverTime
# PercentSalaryHike
# PerformanceRating
# RelationshipSatisfaction
# StandardHours
# StockOptionLevel
# TrainingTimesLastYear
# WorkLifeBalance

# %%
cat_columns = df.columns[df.nunique() <= 15]
cat_columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'Education',
#        'EducationField', 'EmployeeCount', 'EnvironmentSatisfaction', 'Gender',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear',
#        'WorkLifeBalance'],
#       dtype='object')

# %%
cat_columns = df.columns[df.nunique() > 15]
cat_columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'EmployeeNumber', 'HourlyRate',
#        'MonthlyIncome', 'MonthlyRate', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Find Id columns and columns where there is only a single unique value

#Single unique -> No information content as data is consistent
drop_columns = df.columns[df.nunique() == 1]
drop_columns
# Out:
# Index(['EmployeeCount', 'Over18', 'StandardHours'], dtype='object')

# %%
df.drop(columns=['EmployeeCount', 'Over18', 'StandardHours'], inplace=True)

# %%
df.drop(columns=['EmployeeNumber'],inplace=True) # Id column is not useful

# %%
df.shape
# Out:
# (1470, 31)

# %% [markdown]
#  Remove repeated rows

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1470, 31)

# %% [markdown]
# Handle or encode columns which are numbers

# %%
# Find the object columns
obj_cols =  df.select_dtypes(include="object")

# %%
# Find the object columns
obj_cols =  df.select_dtypes(include="object").columns
obj_cols
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'OverTime'],
#       dtype='object')

# %%
object_columns_alternative = []
for col in df.columns:
    if df[col].dtype == 'object':
        object_columns_alternative.append(col)

print(object_columns_alternative)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']

# %%
# Convert String to columns

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %% [markdown]
# - Nominal --> One hot encoding(dummy variables)
# - Ordinal --> label encoding

# %%
# label encoding
label_map = {'BusinessTravel':{'Travel_Rarely':1,'Travel_Frequently':2,'Non-Travel':0}}
df.replace(label_map,inplace=True)
df['BusinessTravel'].unique()
# Out:
# /tmp/ipykernel_3199/298760450.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(label_map,inplace=True)
# array([1, 2, 0])

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel               int64
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# ...

# %%
# OHE
df_ohe = pd.get_dummies(df)
df_ohe.shape,df.shape
# Out:
# ((1470, 51), (1470, 31))

# %%
df_ohe.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition_No',
#        'Attrition_Yes', 'Department_Human Resources',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Human Resources', 'EducationField_Life Sciences',
#        'EducationField_Marketing', 'EducationField_Medical',
#        'EducationField_Other', 'EducationField_Technical Degree',
#        'Gender_Female', 'Gender_Male', 'JobRole_Healthcare Representative',
# ...

# %%
df_ohe.fillna(df_ohe.median, inplace=True)

# %%
cont_columns = df_ohe.columns[df_ohe.nunique() > 15]
cont_columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome',
#        'MonthlyRate', 'TotalWorkingYears', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_ohe.loc[:,cont_columns] = sc.fit_transform(df_ohe.loc[:,cont_columns])
df_ohe.loc[:,cont_columns].mean()
#df_ohe_scaled = sc.fit_transform(df_ohe)
# Out:
# Age                       -6.042030e-18
# DailyRate                  1.208406e-17
# DistanceFromHome           4.833624e-18
# HourlyRate                -4.833624e-18
# MonthlyIncome             -2.416812e-18
# MonthlyRate                4.833624e-18
# TotalWorkingYears         -1.208406e-18
# YearsAtCompany            -4.833624e-18
# YearsInCurrentRole         1.208406e-17
# YearsSinceLastPromotion   -8.458842e-18
# YearsWithCurrManager       0.000000e+00
# dtype: float64

# %%
df_ohe_scaled = pd.DataFrame(df_ohe_scaled, columns=df_ohe.columns)
df_ohe_scaled.head()
# Out:
#         Age  BusinessTravel  DailyRate  DistanceFromHome  Education  \
# 0  0.446350       -0.162399   0.742527         -1.010909  -0.891688
# 1  1.322365        1.717339  -1.297775         -0.147150  -1.868426
# 2  0.008343       -0.162399   1.414363         -0.887515  -0.891688
# 3 -0.429664        1.717339   1.461466         -0.764121   1.061787
# 4 -1.086676       -0.162399  -0.524295         -0.887515  -1.868426
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                -0.660531    1.383138        0.379672 -0.057788
# 1                 0.254625   -0.240677       -1.026167 -0.057788
# 2                 1.169781    1.284725       -1.026167 -0.961486
# 3                 1.169781   -0.486709        0.379672 -0.961486
# 4                -1.575686   -1.274014        0.379672 -0.961486
#
#    JobSatisfaction  ...  JobRole_Manufacturing Director  \
# 0         1.153254  ...                       -0.330808
# ...

# %%
df_ohe_scaled.mean()
# Out:
# Age                                 -3.504377e-17
# BusinessTravel                      -1.643432e-16
# DailyRate                            5.075305e-17
# DistanceFromHome                     4.350262e-17
# Education                            7.008755e-17
# EnvironmentSatisfaction              1.305078e-16
# HourlyRate                           1.691768e-16
# JobInvolvement                       6.525392e-17
# JobLevel                            -2.658493e-17
# JobSatisfaction                     -9.183886e-17
# MonthlyIncome                       -4.471102e-17
# MonthlyRate                          3.021015e-17
# NumCompaniesWorked                   1.450087e-17
# PercentSalaryHike                    2.271803e-16
# PerformanceRating                   -6.114534e-16
# RelationshipSatisfaction             9.667248e-17
# StockOptionLevel                     6.767074e-17
# TotalWorkingYears                   -1.208406e-18
# TrainingTimesLastYear                8.700523e-17
# ...

# %% [markdown]
# Tasks on Heart disease dataset
#
# Load the dataset in a pandas dataframe
# Q1. Rename column V1 to "Serial No"
#
# Q2. Drop column V2
#
# Q3. In column V5, V6, V7, V8, and V9 replace -9 with np.nan (NA)
#
# Q4. In V12 column replace -9 value with mean of this column
#
# Q5. Replace -9 in all columns with np.nan(NA)
#
# Q6. Count number of NA in every column
#
# Q7. Drop columns where percentage of NA is greater than 90%
#
# Q8. Find columns where number of unique values are less than or
# equal to 10.
# For example, V4 has two unique values 0 and 1.
#
# Q9. Find columns where number of unique values are greater than 10.
# For example, V3 has many unique values.
#
# Q10. Find how many values in V58 are 0, 1 and 2.
#
# Q11. In column V58 convert all 2s in 1s.
#
# Q12. Save  this data frame as a new csv file

# %%
df  = pd.read_csv('76_attributes_heartdiseases.csv')

# %%
df.dtypes
# Out:
# V1      int64
# V2      int64
# V3      int64
# V4      int64
# V5      int64
#         ...
# V72     int64
# V73     int64
# V74     int64
# V75    object
# V76    object
# Length: 76, dtype: object

# %%
df.shape
# Out:
# (282, 76)

# %%
# 1.
df.rename(columns={'V1': 'Serial No'}, inplace=True)
df.head()
# Out:
#    Serial No  V2  V3  V4  V5  V6  V7  V8  V9  V10  ...  V67  V68  V69  V70  \
# 0          1   0  63   1  -9  -9  -9  -9   1  145  ...    1    1    1    1
# 1          2   0  67   1  -9  -9  -9  -9   4  160  ...    1    1    1    1
# 2          3   0  67   1  -9  -9  -9  -9   4  120  ...    2    2    1    1
# 3          4   0  37   1  -9  -9  -9  -9   3  130  ...    1    1    1    1
# 4          6   0  41   0  -9  -9  -9  -9   2  130  ...    1    1    1    1
#
#    V71  V72  V73  V74  V75   V76
# 0    1    1    1   -9   -9  name
# 1    1    1    1   -9   -9  name
# 2    1    7    3   -9   -9  name
# 3    1    1    1   -9   -9  name
# 4    1    1    1   -9   -9  name
#
# [5 rows x 76 columns]

# %%
# 2.
df.drop(columns=['V2'], inplace=True)
df.head()
# Out:
#    Serial No  V3  V4  V5  V6  V7  V8  V9  V10  V11  ...  V67  V68  V69  V70  \
# 0          1  63   1  -9  -9  -9  -9   1  145    1  ...    1    1    1    1
# 1          2  67   1  -9  -9  -9  -9   4  160    1  ...    1    1    1    1
# 2          3  67   1  -9  -9  -9  -9   4  120    1  ...    2    2    1    1
# 3          4  37   1  -9  -9  -9  -9   3  130    0  ...    1    1    1    1
# 4          6  41   0  -9  -9  -9  -9   2  130    1  ...    1    1    1    1
#
#    V71  V72  V73  V74  V75   V76
# 0    1    1    1   -9   -9  name
# 1    1    1    1   -9   -9  name
# 2    1    7    3   -9   -9  name
# 3    1    1    1   -9   -9  name
# 4    1    1    1   -9   -9  name
#
# [5 rows x 75 columns]

# %%
# 3.
import numpy as np
columns_to_replace = ['V5', 'V6', 'V7', 'V8', 'V9']
df[columns_to_replace] = df[columns_to_replace].replace(-9, np.nan)
df.head()
# Out:
#    Serial No  V3  V4  V5  V6  V7  V8  V9  V10  V11  ...  V67  V68  V69  V70  \
# 0          1  63   1 NaN NaN NaN NaN   1  145    1  ...    1    1    1    1
# 1          2  67   1 NaN NaN NaN NaN   4  160    1  ...    1    1    1    1
# 2          3  67   1 NaN NaN NaN NaN   4  120    1  ...    2    2    1    1
# 3          4  37   1 NaN NaN NaN NaN   3  130    0  ...    1    1    1    1
# 4          6  41   0 NaN NaN NaN NaN   2  130    1  ...    1    1    1    1
#
#    V71  V72  V73  V74  V75   V76
# 0    1    1    1   -9   -9  name
# 1    1    1    1   -9   -9  name
# 2    1    7    3   -9   -9  name
# 3    1    1    1   -9   -9  name
# 4    1    1    1   -9   -9  name
#
# [5 rows x 75 columns]

# %%
df['V12'] = df['V12'].replace(-9, np.nan)
df['V12'].head()
# Out:
# 0    233.0
# 1    286.0
# 2    229.0
# 3    250.0
# 4    204.0
# Name: V12, dtype: float64

# %%
# 5.
df['V75'] = df['V75'].replace('name', -9)
df['V75'] = df['V75'].astype(float)
df['V75'] = df['V75'].replace(-9, np.nan)
df = df.replace(-9, np.nan)
df.head()
# Out:
#    Serial No  V3  V4  V5  V6  V7  V8  V9  V10  V11  ...  V67  V68  V69  V70  \
# 0          1  63   1 NaN NaN NaN NaN   1  145    1  ...    1    1    1    1
# 1          2  67   1 NaN NaN NaN NaN   4  160    1  ...    1    1    1    1
# 2          3  67   1 NaN NaN NaN NaN   4  120    1  ...    2    2    1    1
# 3          4  37   1 NaN NaN NaN NaN   3  130    0  ...    1    1    1    1
# 4          6  41   0 NaN NaN NaN NaN   2  130    1  ...    1    1    1    1
#
#    V71  V72  V73  V74  V75   V76
# 0    1    1  1.0  NaN  NaN  name
# 1    1    1  1.0  NaN  NaN  name
# 2    1    7  3.0  NaN  NaN  name
# 3    1    1  1.0  NaN  NaN  name
# 4    1    1  1.0  NaN  NaN  name
#
# [5 rows x 75 columns]

# %%
# 6.
df.isna().sum()
# Out:
# Serial No      0
# V3             0
# V4             0
# V5           282
# V6           282
#             ...
# V72            0
# V73            7
# V74          282
# V75          282
# V76            7
# Length: 75, dtype: int64

# %%
v30_null_percentage = df['V30'].isna().mean() * 100
print(f"Percentage of null values in V30: {v30_null_percentage:.2f}%")
# Out:
# Percentage of null values in V30: 24.47%

# %%
#7.
df1 = df.columns[df.isna().sum()/len(df) * 100 > 90]
df.drop(columns=df1, inplace=True)

#df.dropna(thresh=0.9*len(df), axis=1, inplace=True)
df.columns
# Out:
# Index(['Serial No', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V15', 'V16',
#        'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37',
#        'V38', 'V39', 'V40', 'V41', 'V43', 'V44', 'V51', 'V55', 'V56', 'V57',
#        'V58', 'V59', 'V60', 'V61', 'V63', 'V65', 'V67', 'V68', 'V69', 'V70',
#        'V71', 'V72', 'V73', 'V76'],
#       dtype='object')

# %% [markdown]
# df1 = df.columns[df.isna().sum()/len(df) * 100 > 90]
# df.drop(columns=df1, inplace=True)
# df.columns
# Index(['Serial No', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V15', 'V16',
#        'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37',
#        'V38', 'V39', 'V40', 'V41', 'V43', 'V44', 'V51', 'V55', 'V56', 'V57',
#        'V58', 'V59', 'V60', 'V61', 'V63', 'V65', 'V67', 'V68', 'V69', 'V70',
#        'V71', 'V72', 'V73', 'V76'],
#       dtype='object')

# %% [markdown]
# df.dropna(thresh=0.9*len(df), axis=1, inplace=True)
# df.columns
# Index(['Serial No', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V15', 'V16',
#        'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'V29', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38',
#        'V39', 'V40', 'V41', 'V43', 'V44', 'V51', 'V55', 'V56', 'V57', 'V58',
#        'V59', 'V60', 'V61', 'V63', 'V65', 'V67', 'V68', 'V69', 'V70', 'V71',
#        'V72', 'V73', 'V76'],
#       dtype='object')

# %%
df.shape
# Out:
# (282, 54)

# %%
# 8.
df.columns[df.nunique() <= 10]
# Out:
# Index(['V4', 'V9', 'V11', 'V16', 'V18', 'V19', 'V22', 'V23', 'V24', 'V25',
#        'V26', 'V27', 'V28', 'V38', 'V39', 'V41', 'V44', 'V51', 'V57', 'V58',
#        'V59', 'V60', 'V61', 'V63', 'V65', 'V67', 'V68', 'V69', 'V70', 'V71',
#        'V72', 'V73', 'V76'],
#       dtype='object')

# %%
# 9.
df.columns[df.nunique() > 10]
# Out:
# Index(['Serial No', 'V3', 'V10', 'V12', 'V14', 'V15', 'V20', 'V21', 'V29',
#        'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V40', 'V43',
#        'V55', 'V56'],
#       dtype='object')

# %%
# 10.
df['V58'].value_counts()
# Out:
# V58
# 0    154
# 1     53
# 3     32
# 2     31
# 4     12
# Name: count, dtype: int64

# %%
# 11.
df['V58'] = df['V58'].replace(2,1)
df['V58'].value_counts()
# Out:
# V58
# 0    154
# 1     84
# 3     32
# 4     12
# Name: count, dtype: int64

# %%
# 12.
df.to_csv('heartdiseases.csv')
